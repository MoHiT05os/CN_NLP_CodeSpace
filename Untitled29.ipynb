# %% [markdown]
# <a href="https://colab.research.google.com/github/MoHiT05os/CN_NLP_CodeSpace/blob/main/Untitled29.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Experiment 2.1:  Write a Python program to perform basic text preprocessing on a given data. The program should:
#
# ---
#
#
# ### 1.Convert text to lowercase. (Also display how many uppercase?)
# ### 2.Remove punctuation.        (Also display how many different types of        punctuations?)
# ### 3.Remove numbers.            (Also display how many numbers?)
# ### 4.Remove extra whitespace. (How much extra whitespace is present?)
# ### 5.Display the cleaned text.

# %%
import pandas as pd
import string

# %%
uppercase_count = sum(1 for char in text_data if char.isupper())

print(f"Number of uppercase letters: {uppercase_count}")

lower_case=text_data.lower()
print(lower_case)
# Out:
# Number of uppercase letters: 32
# natural language processing (nlp) is a branch of artificial intelligence.  it helps computers understand and process human language.
#
# in 2026, nlp is used in many applications such as chatbots, machine translation, sentiment analysis, and text summarization!!!
#
# text preprocessing is an important step in nlp.   it includes several operations such as cleaning text, removing punctuation, and removing unnecessary numbers.
#
# for example, a chatbot may process 1000+ customer messages every day. these messages can contain capital letters, numbers like 12345, punctuation marks!!!, and   extra spaces.
#
# the main goal of text preprocessing is to convert raw text into a clean and consistent format. this makes the text easier to analyze and use for further natural language processing tasks.

# %%
punctuation=set()
for char in text_data:
  if char in string.punctuation:
    punctuation.add(char)
text_remove_punctaution=lower_case.translate(str.maketrans('', '', string.punctuation))
print(text_remove_punctaution)
# Out:
# natural language processing nlp is a branch of artificial intelligence  it helps computers understand and process human language
#
# in 2026 nlp is used in many applications such as chatbots machine translation sentiment analysis and text summarization
#
# text preprocessing is an important step in nlp   it includes several operations such as cleaning text removing punctuation and removing unnecessary numbers
#
# for example a chatbot may process 1000 customer messages every day these messages can contain capital letters numbers like 12345 punctuation marks and   extra spaces
#
# the main goal of text preprocessing is to convert raw text into a clean and consistent format this makes the text easier to analyze and use for further natural language processing tasks

# %%
number_cnt=sum(1 for char in text_remove_punctaution if char.isdigit())
text_without_num=''.join([char for char in text_remove_punctaution if not char.isdigit()])

print(number_cnt)
print(text_without_num)
# Out:
# 13
# natural language processing nlp is a branch of artificial intelligence  it helps computers understand and process human language
#
# in  nlp is used in many applications such as chatbots machine translation sentiment analysis and text summarization
#
# text preprocessing is an important step in nlp   it includes several operations such as cleaning text removing punctuation and removing unnecessary numbers
#
# for example a chatbot may process  customer messages every day these messages can contain capital letters numbers like  punctuation marks and   extra spaces
#
# the main goal of text preprocessing is to convert raw text into a clean and consistent format this makes the text easier to analyze and use for further natural language processing tasks

# %%
import re
original_length=len(text_without_num)
clean_text=re.sub('\s+',' ',text_without_num).strip()
extra_whitespace_count=original_length-len(clean_text)-text_without_num.count(' ')+clean_text.count(' ')
print(extra_whitespace_count)
print(clean_text)
# Out:
# 8
# natural language processing nlp is a branch of artificial intelligence it helps computers understand and process human language in nlp is used in many applications such as chatbots machine translation sentiment analysis and text summarization text preprocessing is an important step in nlp it includes several operations such as cleaning text removing punctuation and removing unnecessary numbers for example a chatbot may process customer messages every day these messages can contain capital letters numbers like punctuation marks and extra spaces the main goal of text preprocessing is to convert raw text into a clean and consistent format this makes the text easier to analyze and use for further natural language processing tasks
# <>:3: SyntaxWarning: invalid escape sequence '\s'
# <>:3: SyntaxWarning: invalid escape sequence '\s'
# /tmp/ipykernel_5136/3403099605.py:3: SyntaxWarning: invalid escape sequence '\s'
#   clean_text=re.sub('\s+',' ',text_without_num).strip()

# %%
print(clean_text)
# Out:
# natural language processing nlp is a branch of artificial intelligence it helps computers understand and process human language in nlp is used in many applications such as chatbots machine translation sentiment analysis and text summarization text preprocessing is an important step in nlp it includes several operations such as cleaning text removing punctuation and removing unnecessary numbers for example a chatbot may process customer messages every day these messages can contain capital letters numbers like punctuation marks and extra spaces the main goal of text preprocessing is to convert raw text into a clean and consistent format this makes the text easier to analyze and use for further natural language processing tasks

# %% [markdown]
# Experiment 2.2: Write a Python program to perform word tokenization and sentence tokenization on a given text.
# ###
# Display the resulting words and sentences separately.
#            (Three separate code: using NLTK, using spaCy  and without using NLTK/spacy)

# %%
import nltk
nltk.download('punkt')
nltk.download('punkt_tab')
from nltk.tokenize import word_tokenize, sent_tokenize

text=word_tokenize(clean_text)
print(text)
text_sent=sent_tokenize(clean_text)
print(clean_text)
# Out:
# ['natural', 'language', 'processing', 'nlp', 'is', 'a', 'branch', 'of', 'artificial', 'intelligence', 'it', 'helps', 'computers', 'understand', 'and', 'process', 'human', 'language', 'in', 'nlp', 'is', 'used', 'in', 'many', 'applications', 'such', 'as', 'chatbots', 'machine', 'translation', 'sentiment', 'analysis', 'and', 'text', 'summarization', 'text', 'preprocessing', 'is', 'an', 'important', 'step', 'in', 'nlp', 'it', 'includes', 'several', 'operations', 'such', 'as', 'cleaning', 'text', 'removing', 'punctuation', 'and', 'removing', 'unnecessary', 'numbers', 'for', 'example', 'a', 'chatbot', 'may', 'process', 'customer', 'messages', 'every', 'day', 'these', 'messages', 'can', 'contain', 'capital', 'letters', 'numbers', 'like', 'punctuation', 'marks', 'and', 'extra', 'spaces', 'the', 'main', 'goal', 'of', 'text', 'preprocessing', 'is', 'to', 'convert', 'raw', 'text', 'into', 'a', 'clean', 'and', 'consistent', 'format', 'this', 'makes', 'the', 'text', 'easier', 'to', 'analyze', 'an
# ...

# %%
import spacy
file_path="/content/2.2_tokenization_data.txt"
nlp = spacy.load("en_core_web_sm")
with open(file_path,'r') as file:
  text_second=file.read()

doc=nlp(text_second)
tokens=[token.text for token in doc]
print(tokens)


print("--- SENTENCE TOKENIZATION ---")
sentences = [sent.text.strip() for sent in doc.sents]
for i, sentence in enumerate(sentences[:5], 1):
    print(f"Sentence {i}: {sentence}")


print("\n--- WORD TOKENIZATION ---")
words = [token.text for token in doc]
print(f"Total words extracted: {len(words)}")
print(f"First 20 words: {words[:20]}")
# Out:
# ['Natural', 'Language', 'Processing', '(', 'NLP', ')', 'is', 'a', 'fascinating', 'field', 'of', 'Artificial', 'Intelligence', '.', 'It', 'enables', 'computers', 'to', 'understand', 'human', 'language', '.', 'NLP', 'is', 'used', 'in', 'many', 'real', '-', 'world', 'applications', ',', 'such', 'as', 'chatbots', ',', 'machine', 'translation', ',', 'sentiment', 'analysis', ',', 'and', 'text', 'summarization', '.', '\n\n', 'Text', 'tokenization', 'is', 'one', 'of', 'the', 'first', 'steps', 'in', 'NLP', '.', 'Sentence', 'tokenization', 'divides', 'a', 'paragraph', 'into', 'individual', 'sentences', '.', 'Word', 'tokenization', 'divides', 'each', 'sentence', 'into', 'individual', 'words', 'and', 'tokens', '.', '\n\n', 'For', 'example', ',', 'a', 'chatbot', 'receives', 'thousands', 'of', 'messages', 'every', 'day', '.', 'The', 'system', 'processes', 'these', 'messages', 'and', 'identifies', 'useful', 'information', '.', 'This', 'information', 'can', 'then', 'be', 'used', 'to', 'provide', 'be
# ...

# %%
sentence_pattern = r'(?<!\bDr)(?<!\bMr)(?<!\bMs)[.!?]\s+(?=[A-Z0-9])'


raw_sentences = re.split(sentence_pattern, text_second)
sentences = []


current_pos = 0
for s in raw_sentences:
    s = s.strip()
    if not s:
        continue

    start_idx = text_data.find(s, current_pos)
    end_idx = start_idx + len(s)


    if end_idx < len(text_data) and text_data[end_idx] in ['.', '!', '?']:
        sentences.append(s + text_data[end_idx])
        current_pos = end_idx + 1
    else:
        sentences.append(s)
        current_pos = end_idx

print("--- SENTENCE TOKENIZATION ---")
for i, sentence in enumerate(sentences, 1):
    print(f"Sentence {i}: {sentence}")

word_pattern = r"\w+(?:'\w+)?|\d+\.\d+|\$?\d+|\w+|[^\w\s]"

words = re.findall(word_pattern, text_second)

print("\n--- WORD TOKENIZATION ---")
print(f"Total words extracted: {len(words)}")
print(f"Tokens list: {words}")
# Out:
# --- SENTENCE TOKENIZATION ---
# Sentence 1: Natural Language Processing (NLP) is a fascinating field of Artificial Intelligence
# Sentence 2: It enables computers to understand human language
# Sentence 3: NLP is used in many real-world applications, such as chatbots, machine translation, sentiment analysis, and text summarization
# Sentence 4: Text tokenization is one of the first steps in NLP
# Sentence 5: Sentence tokenization divides a paragraph into individual sentences
# Sentence 6: Word tokenization divides each sentence into individual words and tokens
# Sentence 7: For example, a chatbot receives thousands of messages every day
# Sentence 8: The system processes these messages and identifies useful information
# Sentence 9: This information can then be used to provide better responses to users.
#
# --- WORD TOKENIZATION ---
# Total words extracted: 112
# ...

# %% [markdown]
# # Experiment 2.3: Write a Python program to tokenize a text and remove commonly occurring stop words such as is, the, a, an, in, of, and, to, etc.
# ###
# Display the original and filtered tokens. (Also, display Stop Words Separately).
